# %% [markdown]
# # Analysing Oxford Area to invest on property market
#
# ## Background
#
# The housing market is under the pressure at the moment with number of sales going down. According to Knight Frank the market will see about 3% drop during pandemic, but then it will go up by 5% and further.
# With mortages rates low it is a opportunity to invest in the property market.
# The valuation of real estate comes from traditional and non-traditional feautures of the property. Traditional are being size, type of the property, year build etc. Non-traditional are proximity to points of interests, number cafe and reataraunts, hotels, transportation etc.
# Accroding to McKinsey reserch up to 60% of property performance can come from non-traditional feautures.
#
# ## Business Problem
#
# Current lockdown restriction on people's moves makes impossible to evaluate the housing area. Even during noraml period it will take a long time to understand the area for potential investment. Data Science methodology can help to understand the area and accelerate the research for the investment decision making.
#
# ## Data Section
#
# We will create a data frame of local housing prices to Luckily the housing market data is publicly available from the government data base https://www.gov.uk/government/statistical-data-sets/price-paid-data-downloads. We can download the data containing
# - Postcode
# - PAON (Primary Addressable Object Name)
# - Typically the house number or name
# - SAON (Secondary Addressable Object Name.If there is a sub-building, for example, the building is divided into flats, there will be a SAON.)
# - Street
# - Locality
# - Town/City
# - District
# - County
#
# To discover local amenities and facilities we will use FourSquare API. We will created a data frame of local venues and visualize it. We will then combine FourSquare API and housing data frames and cluster them to define the best areas for buying a property.
#
# ## Workflow
#
# The following workflow will be used in this project.
#
#     1. Data collection
#     2. Data inspection and understanding
#     3. Data preparation and processing
#     4. Data modelling using k-Nearest Neighbor Algorithm
#     5. Visualization
#     6. Summary of the project results

# %% [markdown]
# ## 1. Data collection
#
# Let's install all necessary libraries and download the data set. I will be using the data set for 2019 as it is should have better representation of prices and enough number of transactions to explore.

# %%
#Importing all neccessary libraries
import numpy as np
import pandas as pd
import datetime as dt
import requests

#to handle JSON files
import json
from pandas.io.json import json_normalize

#To handle location coordinates
# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim

#import Matplotlib for plotting
import matplotlib.cm as cm
import matplotlib.colors as colors

#for maps intsall Folium
# !conda install -c conda-forge folium=0.5.0 --yes

print('All libraries installed and imported')
# Out:
# /bin/bash: conda: command not found
# /bin/bash: conda: command not found
# All libraries installed and imported

# %%
#Let's import housing sales data from Land registry data base and create data frame
df_land = pd.read_csv("http://prod.publicdata.landregistry.gov.uk.s3-website-eu-west-1.amazonaws.com/pp-2019.csv")

# %% [markdown]
# ## 2. Data inspection and understanding
#
# Let's have a look at the data and understand it first.

# %%
#display first 5 rows of the data set
df_land.head()
# Out:
#    {8F1B26BD-60CA-53DB-E053-6C04A8C03649}  221950  ...  A A.1
# 0  {8F1B26BD-60CB-53DB-E053-6C04A8C03649}  246995  ...  A   A
# 1  {8F1B26BD-60CC-53DB-E053-6C04A8C03649}  244950  ...  A   A
# 2  {8F1B26BD-60CD-53DB-E053-6C04A8C03649}  139950  ...  A   A
# 3  {8F1B26BD-60CE-53DB-E053-6C04A8C03649}  271995  ...  A   A
# 4  {8F1B26BD-60CF-53DB-E053-6C04A8C03649}   84450  ...  A   A
#
# [5 rows x 16 columns]

# %%
#find out how many rows and columns data set contains
df_land.shape
# Out:
# (963682, 16)

# %% [markdown]
# ## 3. Data preparation and processing
#
# The data set from Lang registry contains 16 columns and 963682 rows We will need to re-name the columns to a sensible names, filter the location to Oxford, format date column, group data by post code and calculate average price, assign geographical coordinates to each location and plot the data.

# %%
#first we need meaningful names to the headers of the columns
df_land.columns = ['Transaction', 'Price', 'Date', 'Postcode', 'Type', 'Newbuild', 'Duration', 'PAON', 'SAON', 'Street', 
                   'Neighborhood', 'Town', 'District', 'County', 'Cat_Type', 'Record']

df_land.head()
# Out:
#                               Transaction   Price  ... Cat_Type Record
# 0  {8F1B26BD-60CB-53DB-E053-6C04A8C03649}  246995  ...        A      A
# 1  {8F1B26BD-60CC-53DB-E053-6C04A8C03649}  244950  ...        A      A
# 2  {8F1B26BD-60CD-53DB-E053-6C04A8C03649}  139950  ...        A      A
# 3  {8F1B26BD-60CE-53DB-E053-6C04A8C03649}  271995  ...        A      A
# 4  {8F1B26BD-60CF-53DB-E053-6C04A8C03649}   84450  ...        A      A
#
# [5 rows x 16 columns]

# %%
#next step is to filter data set to Oxford only and see the size of the data frame
df_oxf = df_land.query("Town == 'OXFORD'")
df_oxf.shape
# Out:
# (1831, 16)

# %%
df_oxf
# Out:
#                                    Transaction    Price  ... Cat_Type Record
# 3381    {919FEC06-2C95-9A90-E053-6C04A8C0A300}   145000  ...        B      A
# 3382    {919FEC06-2C99-9A90-E053-6C04A8C0A300}   110000  ...        B      A
# 5054    {919FEC06-2CBE-9A90-E053-6C04A8C0A300}   309000  ...        B      A
# 5055    {919FEC06-2CBF-9A90-E053-6C04A8C0A300}   275000  ...        B      A
# 5057    {919FEC06-2CC1-9A90-E053-6C04A8C0A300}   400000  ...        B      A
# ...                                        ...      ...  ...      ...    ...
# 962602  {919FEC06-2C7C-9A90-E053-6C04A8C0A300}   361000  ...        B      A
# 962603  {919FEC06-2C7D-9A90-E053-6C04A8C0A300}  2400000  ...        B      A
# 962604  {919FEC06-2C7F-9A90-E053-6C04A8C0A300}   975000  ...        B      A
# 962606  {919FEC06-2C81-9A90-E053-6C04A8C0A300}   910000  ...        B      A
# 962607  {919FEC06-2C83-9A90-E053-6C04A8C0A300}      600  ...        B      A
#
# [1831 rows x 16 columns]

# %%
#our data set has non defined neighborhood which belongs to Oxford itself
#let's replace NaN valuse with the city name
df_oxf['Neighborhood'] = df_oxf['Neighborhood'].fillna('OXFORD')
df_oxf
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                    Transaction    Price  ... Cat_Type Record
# 3381    {919FEC06-2C95-9A90-E053-6C04A8C0A300}   145000  ...        B      A
# 3382    {919FEC06-2C99-9A90-E053-6C04A8C0A300}   110000  ...        B      A
# 5054    {919FEC06-2CBE-9A90-E053-6C04A8C0A300}   309000  ...        B      A
# 5055    {919FEC06-2CBF-9A90-E053-6C04A8C0A300}   275000  ...        B      A
# 5057    {919FEC06-2CC1-9A90-E053-6C04A8C0A300}   400000  ...        B      A
# ...                                        ...      ...  ...      ...    ...
# 962602  {919FEC06-2C7C-9A90-E053-6C04A8C0A300}   361000  ...        B      A
# 962603  {919FEC06-2C7D-9A90-E053-6C04A8C0A300}  2400000  ...        B      A
# 962604  {919FEC06-2C7F-9A90-E053-6C04A8C0A300}   975000  ...        B      A
# 962606  {919FEC06-2C81-9A90-E053-6C04A8C0A300}   910000  ...        B      A
# 962607  {919FEC06-2C83-9A90-E053-6C04A8C0A300}      600  ...        B      A
#
# [1831 rows x 16 columns]

# %%
#grouping the results by neighborhood and average price
df_ox_price = df_oxf.groupby(['Street', 'Postcode'])['Price'].mean().reset_index()
df_ox_price.columns = ['Street', 'Postcode','Price_av']
df_ox_price
# Out:
#              Street Postcode  Price_av
# 0        ABBEY ROAD  OX2 0AD  640000.0
# 1     ABINGDON ROAD  OX1 4TJ  360000.0
# 2     ABINGDON ROAD  OX2 9QN  455000.0
# 3      ABLETT CLOSE  OX4 1XH  355000.0
# 4        ACRE CLOSE  OX3 7FQ  368000.0
# ...             ...      ...       ...
# 1173      YEW CLOSE  OX4 7UX  160000.0
# 1174    YORK AVENUE  OX3 8NS  325000.0
# 1175     YORK PLACE  OX4 1YL  581000.0
# 1176      YORK ROAD  OX3 8NP  600000.0
# 1177      YORK ROAD  OX3 8NW  561500.0
#
# [1178 rows x 3 columns]

# %%
#Download Location coordinates for Oxford
address = 'Oxford, UK'
geolocator = Nominatim(user_agent = "oxy")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geografical location of Oxford is {}, {}.'.format(latitude, longitude))
# Out:
# The geografical location of Oxford is 51.7520131, -1.2578499.

# %%
#find out geografical location of postcodes
#download UK post codes geografical locations from open source
# !wget https://www.freemaptools.com/download/full-postcodes/ukpostcodes.zip
# Out:
# --2020-05-10 08:02:01--  https://www.freemaptools.com/download/full-postcodes/ukpostcodes.zip
# Resolving www.freemaptools.com (www.freemaptools.com)... 208.97.137.162, 2607:f298:5:101a::e06:9b6c
# Connecting to www.freemaptools.com (www.freemaptools.com)|208.97.137.162|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33130126 (32M) [application/zip]
# Saving to: ‘ukpostcodes.zip’
#
# ukpostcodes.zip     100%[===================>]  31.59M  9.39MB/s    in 4.6s
#
# 2020-05-10 08:02:07 (6.86 MB/s) - ‘ukpostcodes.zip’ saved [33130126/33130126]

# %%
#Create data frame with locations coordinates
loc = pd.read_csv('ukpostcodes.zip')
loc.columns = ['id', 'postcode', 'latitude', 'longitude']
loc.head()
# Out:
#    id  postcode   latitude  longitude
# 0   1  AB10 1XG  57.144165  -2.114848
# 1   2  AB10 6RN  57.137880  -2.121487
# 2   3  AB10 7JB  57.124274  -2.127190
# 3   4  AB11 5QN  57.142701  -2.093295
# 4   5  AB11 6UL  57.137547  -2.112233

# %%
#let's remove id column
loc = loc.drop(columns = ['id'])
loc.head()
# Out:
#    postcode   latitude  longitude
# 0  AB10 1XG  57.144165  -2.114848
# 1  AB10 6RN  57.137880  -2.121487
# 2  AB10 7JB  57.124274  -2.127190
# 3  AB11 5QN  57.142701  -2.093295
# 4  AB11 6UL  57.137547  -2.112233

# %%
#and standardize the header
col = ['Postcode', 'Latitude', 'Longitude']
loc.columns = col
loc.head()
# Out:
#    Postcode   Latitude  Longitude
# 0  AB10 1XG  57.144165  -2.114848
# 1  AB10 6RN  57.137880  -2.121487
# 2  AB10 7JB  57.124274  -2.127190
# 3  AB11 5QN  57.142701  -2.093295
# 4  AB11 6UL  57.137547  -2.112233

# %%
#now let' merge two data frames to match the post code
oxford_data = pd.merge(df_ox_price,
                 loc[['Postcode', 'Latitude', 'Longitude']],
                 on='Postcode')
oxford_data.head()
# Out:
#           Street Postcode  Price_av   Latitude  Longitude
# 0     ABBEY ROAD  OX2 0AD  640000.0  51.754412  -1.271848
# 1  ABINGDON ROAD  OX1 4TJ  360000.0  51.734051  -1.249716
# 2  ABINGDON ROAD  OX2 9QN  455000.0  51.733564  -1.331408
# 3   ABLETT CLOSE  OX4 1XH  355000.0  51.749103  -1.233127
# 4     ACRE CLOSE  OX3 7FQ  368000.0  51.744058  -1.197857

# %% [markdown]
# Thus we have got the data frame with postcodes matching to locations coordinates.
#
# Now to narrow our research let's chose properties with a price close to avearge range. The average price for Oxford £500k accourding to real estate agents portal Zoopla.

# %%
#Average price for property in Oxford is £500k. Let's chose properties between £450 and £550k
ox_av = oxford_data.query("(Price_av >= 450000) & (Price_av <= 550000)")
ox_av
# Out:
#                Street  Postcode  Price_av   Latitude  Longitude
# 2       ABINGDON ROAD   OX2 9QN  455000.0  51.733564  -1.331408
# 5       ACREMEAD ROAD  OX33 1NZ  487500.0  51.745725  -1.154707
# 10       ALDRICH ROAD   OX2 7SS  492500.0  51.785151  -1.261481
# 28    ARLINGTON DRIVE   OX3 0SL  497500.0  51.768291  -1.242917
# 33     ASHCROFT CLOSE   OX2 9SE  492500.0  51.750896  -1.312104
# ...               ...       ...       ...        ...        ...
# 1133      WOLSEY ROAD   OX2 7TA  468000.0  51.787217  -1.264100
# 1135   WOOD AVENS WAY   OX3 9GA  545000.0  51.771410  -1.216918
# 1145   WOODPERRY ROAD   OX3 9UZ  550000.0  51.793918  -1.176281
# 1147  WOODSTOCK CLOSE   OX2 8DB  457500.0  51.784841  -1.273750
# 1149   WOODSTOCK ROAD   OX2 6EY  550000.0  51.762552  -1.263690
#
# [139 rows x 5 columns]

# %%
#next step let create map of Oxford and vicinity with average property prices per post code as markers
import folium
map_ox = folium.Map(location = [latitude, longitude], zoom_start = 13)

#add markers to the map
for lat, lng, street, postcode in zip(ox_av['Latitude'], ox_av['Longitude'], 
                                          ox_av['Postcode'], ox_av['Street']):
    label = '{}, {}'.format(postcode, street)
    label = folium.Popup(label, parse_html = True)
    folium.CircleMarker([lat,lng], radius = 5, popup = label, color = 'blue', 
                        fill = True, fill_color = '#3186cc', fill_opacity = 0.7, parse_html = False).add_to(map_ox)
map_ox
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Looking at the spread of properties around the city we can see that the properties in the price range we have chosen are evenly distributed. Now we can focus our study on the venues available around the city to chose the area with the most diverse venues categories.

# %% [markdown]
# ### Using FourSqure API to create venues data frame
#
# We will downolad the venues available arout Oxford city from FourSquare API and will create the data fame of the most common venues.

# %%
#define FourSquare Credentials
CLIENT_ID = '444DKD1SWHVB3YEZGMRHVDINOLU5MMHBHIJ0FWZ5WLRVKUD2'
CLIENT_SECRET = 'BUCGHUPKJEEE4XAKFSYC2UNDZ3R5F5IAQYMBTCEOCFDGBAXN'
VERSION = '20200501'
print('CLIENT ID:' +CLIENT_ID)
# Out:
# CLIENT ID:444DKD1SWHVB3YEZGMRHVDINOLU5MMHBHIJ0FWZ5WLRVKUD2

# %%
#Let's see the first street in the data frame
ox_av.loc[2, 'Street']
# Out:
# 'ABINGDON ROAD'

# %%
street_name = ox_av.loc[2, 'Street']
street_latitude = ox_av.loc[2, 'Latitude']
street_longitude = ox_av.loc[2, 'Longitude']

print('Coordinates of street {} are {}, {}.'.format(street_name, street_latitude, street_longitude))
# Out:
# Coordinates of street ABINGDON ROAD are 51.733564065696, -1.33140848984531.

# %%
#get top 100 venues in Oxford
LIMIT = 100
radius = 2000

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit{}'.format(
    CLIENT_ID,
    CLIENT_SECRET,
    VERSION,
    street_latitude,
    street_longitude,
    radius,
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=444DKD1SWHVB3YEZGMRHVDINOLU5MMHBHIJ0FWZ5WLRVKUD2&client_secret=BUCGHUPKJEEE4XAKFSYC2UNDZ3R5F5IAQYMBTCEOCFDGBAXN&v=20200501&ll=51.733564065696,-1.33140848984531&radius=2000&limit100'

# %%
#send GET request and examaine the results
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5eb7b75a618f43001b8014ed'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d433e1d15aa8cfab814fb99-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d155941735',
#          'name': 'Gastropub',
#          'pluralName': 'Gastropubs',
#          'primary': True,
#          'shortName': 'Gastropub'}],
#        'id': '4d433e1d15aa8cfab814fb99',
#        'location': {'address': '28 Appleton Rd.',
#         'cc': 'GB',
#         'city': 'Cumnor',
#         'country': 'United Kingdom',
#         'distance': 369,
#         'formattedAddress': ['28 Appleton Rd.',
#          'Cumnor',
#          'Oxfordshire',
#          'OX2 9QH',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.733540421888534,
#           'lng': -1.3367674968497028}],
#         'lat': 51.733540421888534,
#         'lng': -1.3367674968497028,
#         'postalCode': 'OX2 9QH',
#         'state': 'Oxfordshire'},
#        'name': 'The Bear & Ragged Staff',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5159be9be4b03fe72e0056a7-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'primary': True,
#          'shortName': 'Pub'}],
#        'id': '5159be9be4b03fe72e0056a7',
#        'location': {'address': '11 Abingdon Rd',
#         'cc': 'GB',
#         'city': 'Cumnor',
#         'country': 'United Kingdom',
#         'distance': 10,
#         'formattedAddress': ['11 Abingdon Rd',
#          'Cumnor',
#          'Oxfordshire',
#          'OX2 9QN',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.733613402564686,
#           'lng': -1.3312822580337522}],
#         'lat': 51.733613402564686,
#         'lng': -1.3312822580337522,
#         'postalCode': 'OX2 9QN',
#         'state': 'Oxfordshire'},
#        'name': 'The Vine Inn',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5d6eca12fc25180008e719e4-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#           'suffix': '.png'},
#          'id': '545419b1498ea6ccd0202f58',
#          'name': 'Home Service',
#          'pluralName': 'Home Services & Repairs',
#          'primary': True,
#          'shortName': 'Home Services'}],
#        'id': '5d6eca12fc25180008e719e4',
#        'location': {'address': '44 Robsart Place, Cumnor',
#         'cc': 'GB',
#         'city': 'Oxford',
#         'country': 'United Kingdom',
#         'distance': 316,
#         'formattedAddress': ['44 Robsart Place, Cumnor',
#          'Oxford',
#          'Oxfordshire',
#          'OX2 9QT',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.73073669999999,
#           'lng': -1.3319376}],
#         'lat': 51.73073669999999,
#         'lng': -1.3319376,
#         'postalCode': 'OX2 9QT',
#         'state': 'Oxfordshire'},
#        'name': 'Link Security',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f0d6ae04fc6a5312954ce81-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#           'suffix': '.png'},
#          'id': '52e81612bcbc57f1066b7a23',
#          'name': 'Forest',
#          'pluralName': 'Forests',
#          'primary': True,
#          'shortName': 'Forest'}],
#        'id': '4f0d6ae04fc6a5312954ce81',
#        'location': {'address': 'Denton Cl.',
#         'cc': 'GB',
#         'city': 'Cumnor',
#         'country': 'United Kingdom',
#         'distance': 1835,
#         'formattedAddress': ['Denton Cl.',
#          'Cumnor',
#          'Oxfordshire',
#          'OX2 9JJ',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.74637904789502,
#           'lng': -1.3146620193156322}],
#         'lat': 51.74637904789502,
#         'lng': -1.3146620193156322,
#         'neighborhood': 'Dean Court, Oxfordshire',
#         'postalCode': 'OX2 9JJ',
#         'state': 'Oxfordshire'},
#        'name': "Hid's Copse",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5eac68dde38d180007210d4e-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'primary': True,
#          'shortName': 'Park'}],
#        'id': '5eac68dde38d180007210d4e',
#        'location': {'address': 'Denton Cl',
#         'cc': 'GB',
#         'city': 'Oxford',
#         'country': 'United Kingdom',
#         'distance': 1854,
#         'formattedAddress': ['Denton Cl',
#          'Oxford',
#          'Oxfordshire',
#          'OX2 9BW',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.74682,
#           'lng': -1.3151243}],
#         'lat': 51.74682,
#         'lng': -1.3151243,
#         'postalCode': 'OX2 9BW',
#         'state': 'Oxfordshire'},
#        'name': 'Denton Green',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5ea684eec772ce00072cd443-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#           'suffix': '.png'},
#          'id': '52e81612bcbc57f1066b7a23',
#          'name': 'Forest',
#          'pluralName': 'Forests',
#          'primary': True,
#          'shortName': 'Forest'}],
#        'id': '5ea684eec772ce00072cd443',
#        'location': {'address': 'Cumnor Hill',
#         'cc': 'GB',
#         'city': 'Cumnor',
#         'country': 'United Kingdom',
#         'distance': 1187,
#         'formattedAddress': ['Cumnor Hill',
#          'Cumnor',
#          'Oxfordshire',
#          'OX2 9HT',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.73929,
#           'lng': -1.3168762}],
#         'lat': 51.73929,
#         'lng': -1.3168762,
#         'postalCode': 'OX2 9HT',
#         'state': 'Oxfordshire'},
#        'name': 'Long Copse',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5ea6860e196c4100087ed985-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'primary': True,
#          'shortName': 'Historic Site'}],
#        'id': '5ea6860e196c4100087ed985',
#        'location': {'address': "Denman's Ln",
#         'cc': 'GB',
#         'city': 'Cumnor',
#         'country': 'United Kingdom',
#         'distance': 1798,
#         'formattedAddress': ["Denman's Ln",
#          'Cumnor',
#          'Oxfordshire',
#          'OX2 9NH',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.749195,
#           'lng': -1.3248248}],
#         'lat': 51.749195,
#         'lng': -1.3248248,
#         'postalCode': 'OX2 9NH',
#         'state': 'Oxfordshire'},
#        'name': 'Blind Pinnock Ruins',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Current map view',
#   'headerLocation': 'Current map view',
#   'headerLocationGranularity': 'unknown',
#   'suggestedBounds': {'ne': {'lat': 51.75156408369602,
#     'lng': -1.3023985546059746},
#    'sw': {'lat': 51.715564047695985, 'lng': -1.3604184250846454}},
#   'totalResults': 7}}

# %%
#define function that extracs the category of the venue
def get_category_type(row):
  try:
    categories_list = row['categories']
  except:
    categories_list = row['venue.categories']

  if len(categories_list) == 0:
    return None
  else:
    return categories_list[0]['name']

# %%
#create pandas data frame from json file
 venues = results['response']['groups'][0]['items']
 nearby_venues = json_normalize(venues)

 filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
 nearby_venues = nearby_venues.loc[:, filtered_columns]

 nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis = 1)
 nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]
 nearby_venues
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                       name     categories        lat       lng
# 0  The Bear & Ragged Staff      Gastropub  51.733540 -1.336767
# 1             The Vine Inn            Pub  51.733613 -1.331282
# 2            Link Security   Home Service  51.730737 -1.331938
# 3              Hid's Copse         Forest  51.746379 -1.314662
# 4             Denton Green           Park  51.746820 -1.315124
# 5               Long Copse         Forest  51.739290 -1.316876
# 6      Blind Pinnock Ruins  Historic Site  51.749195 -1.324825

# %%
#now we will see how many venues were returned by FourSquare
print('{} venues were returned by FourSquare'.format(nearby_venues.shape[0]))
# Out:
# 7 venues were returned by FourSquare

# %% [markdown]
# After extracting venues for one of teh locations let's do the same process for all of the city. I'm using a large radius as there is no enough venues in a smaller radius

# %%
#the function retrieves venues given the names and coordinates and stores it into data frame
def getNearbyVenues(names, latitudes, longitudes, radius=2000, LIMIT=50):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    ox_venues = pd.DataFrame([item for venues_list in venues_list for item in venues_list])
    ox_venues.columns = ['Street', 
                  'Street Latitude', 
                  'Street Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(ox_venues)

# %%
ox_venues = getNearbyVenues(names=ox_av['Street'],
                              latitudes = ox_av['Latitude'],
                              longitudes = ox_av['Longitude'])
# Out:
# ABINGDON ROAD
# ACREMEAD ROAD
# ALDRICH ROAD
# ARLINGTON DRIVE
# ASHCROFT CLOSE
# BANBURY ROAD
# BERTIE ROAD
# BISHOP KIRK PLACE
# BLUEBELL MEWS
# BOTLEY ROAD
# BOTLEY ROAD
# BOWNESS AVENUE
# BROADHURST GARDENS
# BULLINGDON ROAD
# BUSHY CLOSE
# CHURCH ROAD
# CHURCH ROAD
# COLTERNE CLOSE
# CONISTON AVENUE
# COPPOCK CLOSE
# CORNWALLIS ROAD
# COTSWOLD CRESCENT
# COURTLAND ROAD
# COWLEY ROAD
# COX LANE
# CROWN ROAD
# CUMNOR HILL
# CUMNOR HILL
# CUMNOR ROAD
# CUNLIFFE CLOSE
# DERWENT AVENUE
# DIVINITY ROAD
# DUKE STREET
# EAST AVENUE
# EAST FIELD CLOSE
# EDGEWAY ROAD
# EGERTON ROAD
# EWIN CLOSE
# EYNSHAM ROAD
# FAIR VIEW
# FERRY HINKSEY ROAD
# FISHER ROW
# FLORENCE PARK ROAD
# FOX LANE
# GIDLEY WAY
# HAYNES ROAD
# HEADLEY WAY
# HEADLEY WAY
# HELEN ROAD
# HENLEY ROAD
# HENLEY STREET
# HENLEY STREET
# HENRY ROAD
# HERTFORD STREET
# HIGH STREET
# HIGH STREET
# HOME CLOSE
# HOPE WAY
# HORWOOD CLOSE
# HOWARD STREET
# HOWARD STREET
# HUGH ALLEN CRESCENT
# HUTCHCOMB ROAD
# JACKSON ROAD
# KELLYS ROAD
# KENILWORTH AVENUE
# KINGSTON ROAD
# LANHAM WAY
# LAWN UPTON CLOSE
# LEIDEN ROAD
# LIME WALK
# LONDON ROAD
# LONDON ROAD
# MAGDALEN ROAD
# MAIN STREET
# MANOR DRIVE
# MANOR GROVE
# MARK ROAD
# MARK ROAD
# MARLBOROUGH ROAD
# MARSTON ROAD
# MEADOW PROSPECT
# MOODY ROAD
# MORRELL AVENUE
# NEW ROAD
# NEWINGTON ROAD
# NICHOLSON ROAD
# NORREYS AVENUE
# NORREYS ROAD
# NORREYS ROAD
# NORTH HINKSEY LANE
# OBSERVATORY STREET
# OLD HIGH STREET
# OLD HIGH STREET
# OXFORD ROAD
# OXFORD ROAD
# OXFORD ROAD
# PERCY STREET
# POPLAR GROVE
# PRINCES STREET
# QUARRY ROAD
# RANDOLPH STREET
# RECTORY ROAD
# RECTORY ROAD
# RELIANCE WAY
# ROSE HILL
# RYLANDS
# SHEEPWAY COURT
# SOUTHFIELD ROAD
# ST LEONARDS ROAD
# ST LEONARDS ROAD
# ST PETERS ROAD
# STONE MEADOW
# SUNNINGWELL ROAD
# TEMPLAR ROAD
# TERRETT AVENUE
# THAMES STREET
# THE PARK
# THE SIDINGS
# TIDMARSH LANE
# TREE LANE
# TURNPIKE ROAD
# ULFGAR ROAD
# UNION STREET
# WALTON STREET
# WALTON WELL ROAD
# WARREN HILL
# WELLBORNE ROAD
# WELLBOURNE ROAD
# WEST STREET
# WEST STREET
# WEYLAND ROAD
# WHITE HART
# WHITE ROAD
# WOLSEY ROAD
# WOOD AVENS WAY
# WOODPERRY ROAD
# WOODSTOCK CLOSE
# WOODSTOCK ROAD

# %%
print(ox_venues.shape)
ox_venues.head()
# Out:
# (5129, 7)
#           Street  Street Latitude  ...  Venue Longitude Venue Category
# 0  ABINGDON ROAD        51.733564  ...        -1.336767      Gastropub
# 1  ABINGDON ROAD        51.733564  ...        -1.331282            Pub
# 2  ABINGDON ROAD        51.733564  ...        -1.331938   Home Service
# 3  ABINGDON ROAD        51.733564  ...        -1.314662         Forest
# 4  ABINGDON ROAD        51.733564  ...        -1.315124           Park
#
# [5 rows x 7 columns]

# %% [markdown]
# We have extracted 5129 venues. Now we will group them by street name

# %%
ox_venues.groupby('Street').count()
# Out:
#                  Street Latitude  ...  Venue Category
# Street                            ...
# ABINGDON ROAD                  7  ...               7
# ACREMEAD ROAD                  7  ...               7
# ALDRICH ROAD                  45  ...              45
# ARLINGTON DRIVE               50  ...              50
# ASHCROFT CLOSE                25  ...              25
# ...                          ...  ...             ...
# WOLSEY ROAD                   46  ...              46
# WOOD AVENS WAY                43  ...              43
# WOODPERRY ROAD                 4  ...               4
# WOODSTOCK CLOSE               50  ...              50
# WOODSTOCK ROAD                50  ...              50
#
# [123 rows x 6 columns]

# %% [markdown]
# ### Let's see how many unique venues are in categories

# %%
print('Unique venue categories = ',format(len(ox_venues['Venue Category'].unique())))
# Out:
# Unique venue categories =  128

# %%
#one hot encoding
ox_onehot = pd.get_dummies(ox_venues[['Venue Category']], prefix = "", prefix_sep = "")

#add neighborhood column to the data frame
ox_onehot['Street'] = ox_venues['Street']

fixed_columns = [ox_onehot.columns[-1]]+list(ox_onehot.columns[:-1])
ox_onehot = ox_onehot[fixed_columns]
ox_onehot.head()
# Out:
#           Street  American Restaurant  ...  Warehouse Store  Wine Shop
# 0  ABINGDON ROAD                    0  ...                0          0
# 1  ABINGDON ROAD                    0  ...                0          0
# 2  ABINGDON ROAD                    0  ...                0          0
# 3  ABINGDON ROAD                    0  ...                0          0
# 4  ABINGDON ROAD                    0  ...                0          0
#
# [5 rows x 129 columns]

# %%
#new data frame size
ox_onehot.shape
# Out:
# (5129, 129)

# %%
#grouping rows by neighborhood and by taking mean frequency of occurence of each category
oxford_gr = ox_onehot.groupby('Street').mean().reset_index()
oxford_gr.head()
# Out:
#             Street  American Restaurant  ...  Warehouse Store  Wine Shop
# 0    ABINGDON ROAD                  0.0  ...             0.00       0.00
# 1    ACREMEAD ROAD                  0.0  ...             0.00       0.00
# 2     ALDRICH ROAD                  0.0  ...             0.00       0.00
# 3  ARLINGTON DRIVE                  0.0  ...             0.00       0.00
# 4   ASHCROFT CLOSE                  0.0  ...             0.04       0.04
#
# [5 rows x 129 columns]

# %%
#print each neighborhood along the top 5 most common venues
num_top_venues = 5

for hood in oxford_gr['Street']:
    print("----"+hood+"----")
    temp = oxford_gr[oxford_gr['Street'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----ABINGDON ROAD----
#            venue  freq
# 0         Forest  0.29
# 1  Historic Site  0.14
# 2           Park  0.14
# 3      Gastropub  0.14
# 4            Pub  0.14
#
#
# ----ACREMEAD ROAD----
#              venue  freq
# 0              Pub  0.14
# 1              Gym  0.14
# 2             Food  0.14
# 3  Motorcycle Shop  0.14
# 4    Grocery Store  0.14
#
#
# ----ALDRICH ROAD----
#                 venue  freq
# 0               Hotel  0.16
# 1  Chinese Restaurant  0.07
# 2                 Pub  0.07
# 3       Grocery Store  0.07
# 4         Coffee Shop  0.07
#
#
# ----ARLINGTON DRIVE----
#                 venue  freq
# 0                 Pub  0.12
# 1              Bakery  0.06
# 2      History Museum  0.06
# 3         Coffee Shop  0.06
# 4  Chinese Restaurant  0.04
#
#
# ----ASHCROFT CLOSE----
#                  venue  freq
# 0    Electronics Store  0.12
# 1        Grocery Store  0.08
# 2            Wine Shop  0.04
# 3            Pet Store  0.04
# 4  Sporting Goods Shop  0.04
#
#
# ----BANBURY ROAD----
#                 venue  freq
# 0               Hotel  0.16
# 1                 Pub  0.14
# 2         Coffee Shop  0.08
# 3  Chinese Restaurant  0.06
# 4          Restaurant  0.06
#
#
# ----BERTIE ROAD----
#         venue  freq
# 0    Bus Stop   0.2
# 1      Forest   0.2
# 2  Campground   0.2
# 3   Gastropub   0.2
# 4         Pub   0.2
#
#
# ----BISHOP KIRK PLACE----
#                 venue  freq
# 0                 Pub  0.20
# 1               Hotel  0.15
# 2  Chinese Restaurant  0.07
# 3         Coffee Shop  0.07
# 4   Indian Restaurant  0.05
#
#
# ----BLUEBELL MEWS----
#             venue  freq
# 0   Grocery Store  0.17
# 1             Pub  0.10
# 2            Café  0.10
# 3  Sandwich Place  0.07
# 4     Coffee Shop  0.07
#
#
# ----BOTLEY ROAD----
#           venue  freq
# 0           Pub  0.12
# 1        Bakery  0.06
# 2   Coffee Shop  0.04
# 3    Restaurant  0.04
# 4  Cocktail Bar  0.04
#
#
# ----BOWNESS AVENUE----
#            venue  freq
# 0  Grocery Store  0.16
# 1            Pub  0.14
# 2    Supermarket  0.07
# 3           Park  0.07
# 4           Café  0.07
#
#
# ----BROADHURST GARDENS----
#             venue  freq
# 0  Soccer Stadium  0.22
# 1             Pub  0.17
# 2           Hotel  0.17
# 3   Grocery Store  0.09
# 4   Bowling Alley  0.04
#
#
# ----BULLINGDON ROAD----
#                 venue  freq
# 0                 Pub  0.20
# 1                Café  0.06
# 2      Ice Cream Shop  0.04
# 3    Asian Restaurant  0.04
# 4  Turkish Restaurant  0.04
#
#
# ----BUSHY CLOSE----
#                venue  freq
# 0        Supermarket  0.12
# 1      Grocery Store  0.12
# 2        IT Services  0.06
# 3            Brewery  0.06
# 4  Electronics Store  0.06
#
#
# ----CHURCH ROAD----
#                venue  freq
# 0        Supermarket  0.13
# 1      Grocery Store  0.13
# 2              Hotel  0.07
# 3                Pub  0.07
# 4  Electronics Store  0.07
#
#
# ----COLTERNE CLOSE----
#            venue  freq
# 0  Grocery Store  0.15
# 1            Pub  0.12
# 2           Park  0.10
# 3    Supermarket  0.07
# 4           Café  0.07
#
#
# ----CONISTON AVENUE----
#             venue  freq
# 0   Grocery Store  0.17
# 1             Pub  0.12
# 2            Park  0.07
# 3            Café  0.07
# 4  Sandwich Place  0.07
#
#
# ----COPPOCK CLOSE----
#             venue  freq
# 0             Pub  0.12
# 1     Supermarket  0.10
# 2   Grocery Store  0.10
# 3            Café  0.10
# 4  Sandwich Place  0.07
#
#
# ----CORNWALLIS ROAD----
#                 venue  freq
# 0                 Pub  0.26
# 1  Turkish Restaurant  0.04
# 2        Burger Joint  0.04
# 3                Park  0.04
# 4           Wine Shop  0.02
#
#
# ----COTSWOLD CRESCENT----
#                 venue  freq
# 0                 Pub  0.18
# 1  Chinese Restaurant  0.06
# 2       Grocery Store  0.06
# 3               Hotel  0.06
# 4          Restaurant  0.06
#
#
# ----COURTLAND ROAD----
#             venue  freq
# 0             Pub  0.24
# 1   Grocery Store  0.14
# 2           Hotel  0.06
# 3     Pizza Place  0.06
# 4  Clothing Store  0.04
#
#
# ----COWLEY ROAD----
#                 venue  freq
# 0                 Pub  0.23
# 1    Asian Restaurant  0.04
# 2  Turkish Restaurant  0.04
# 3                Café  0.04
# 4                Park  0.04
#
#
# ----COX LANE----
#                    venue  freq
# 0                    Pub  0.50
# 1              Rest Area  0.25
# 2                   Farm  0.25
# 3  Portuguese Restaurant  0.00
# 4                  Plaza  0.00
#
#
# ----CROWN ROAD----
#                 venue  freq
# 0       Grocery Store   0.2
# 1  English Restaurant   0.1
# 2                 Gym   0.1
# 3                Café   0.1
# 4                Food   0.1
#
#
# ----CUMNOR HILL----
#                venue  freq
# 0        Supermarket  0.12
# 1      Grocery Store  0.12
# 2        IT Services  0.06
# 3            Brewery  0.06
# 4  Electronics Store  0.06
#
#
# ----CUMNOR ROAD----
#                     venue  freq
# 0                     Pub   0.6
# 1  Furniture / Home Store   0.2
# 2               Gastropub   0.2
# 3            Noodle House   0.0
# 4                  Museum   0.0
#
#
# ----CUNLIFFE CLOSE----
#             venue  freq
# 0             Pub  0.20
# 1          Bakery  0.10
# 2           Hotel  0.06
# 3  History Museum  0.06
# 4     Coffee Shop  0.06
#
#
# ----DERWENT AVENUE----
#             venue  freq
# 0   Grocery Store  0.18
# 1             Pub  0.12
# 2  Sandwich Place  0.08
# 3            Park  0.08
# 4            Café  0.08
#
#
# ----DIVINITY ROAD----
#                 venue  freq
# 0                 Pub  0.20
# 1      Ice Cream Shop  0.04
# 2    Asian Restaurant  0.04
# 3  Turkish Restaurant  0.04
# 4                Café  0.04
#
#
# ----DUKE STREET----
#             venue  freq
# 0             Pub  0.10
# 1          Bakery  0.06
# 2    Cocktail Bar  0.04
# 3     Coffee Shop  0.04
# 4  Ice Cream Shop  0.04
#
#
# ----EAST AVENUE----
#                 venue  freq
# 0                 Pub  0.18
# 1                Café  0.06
# 2      Ice Cream Shop  0.04
# 3    Asian Restaurant  0.04
# 4  Turkish Restaurant  0.04
#
#
# ----EAST FIELD CLOSE----
#                     venue  freq
# 0                     Pub  0.18
# 1             Supermarket  0.09
# 2           Grocery Store  0.09
# 3  Furniture / Home Store  0.06
# 4             Coffee Shop  0.06
#
#
# ----EDGEWAY ROAD----
#             venue  freq
# 0             Pub  0.10
# 1      Restaurant  0.06
# 2  History Museum  0.06
# 3  Ice Cream Shop  0.04
# 4     Coffee Shop  0.04
#
#
# ----EGERTON ROAD----
#                     venue  freq
# 0                     Pub  0.26
# 1           Grocery Store  0.12
# 2             Pizza Place  0.06
# 3  Furniture / Home Store  0.04
# 4          Clothing Store  0.04
#
#
# ----EWIN CLOSE----
#             venue  freq
# 0             Pub  0.12
# 1      Restaurant  0.08
# 2   Grocery Store  0.08
# 3            Park  0.08
# 4  Sandwich Place  0.08
#
#
# ----EYNSHAM ROAD----
#                venue  freq
# 0      Grocery Store  0.12
# 1        IT Services  0.06
# 2            Brewery  0.06
# 3  Electronics Store  0.06
# 4            Parking  0.06
#
#
# ----FAIR VIEW----
#            venue  freq
# 0            Pub  0.14
# 1    Supermarket  0.10
# 2  Grocery Store  0.06
# 3           Park  0.06
# 4    Pizza Place  0.04
#
#
# ----FERRY HINKSEY ROAD----
#              venue  freq
# 0              Pub  0.10
# 1           Bakery  0.06
# 2  Thai Restaurant  0.04
# 3       Restaurant  0.04
# 4      Coffee Shop  0.04
#
#
# ----FISHER ROW----
#              venue  freq
# 0              Pub  0.08
# 1             Café  0.06
# 2   History Museum  0.06
# 3  Thai Restaurant  0.04
# 4       Restaurant  0.04
#
#
# ----FLORENCE PARK ROAD----
#           venue  freq
# 0           Pub  0.26
# 1   Pizza Place  0.04
# 2          Park  0.04
# 3  Burger Joint  0.04
# 4     Wine Shop  0.02
#
#
# ----FOX LANE----
#                  venue  freq
# 0                  Pub  0.75
# 1           Campground  0.25
# 2  American Restaurant  0.00
# 3                 Pool  0.00
# 4                Plaza  0.00
#
#
# ----GIDLEY WAY----
#                 venue  freq
# 0                 Pub  0.25
# 1     Motorcycle Shop  0.25
# 2       Grocery Store  0.25
# 3        Home Service  0.25
# 4  Turkish Restaurant  0.00
#
#
# ----HAYNES ROAD----
#                 venue  freq
# 0                 Pub  0.18
# 1               Hotel  0.06
# 2         Coffee Shop  0.06
# 3          Restaurant  0.06
# 4  Chinese Restaurant  0.06
#
#
# ----HEADLEY WAY----
#             venue  freq
# 0             Pub  0.12
# 1            Café  0.06
# 2            Park  0.04
# 3  Sandwich Place  0.04
# 4    Burger Joint  0.04
#
#
# ----HELEN ROAD----
#             venue  freq
# 0             Pub  0.12
# 1     Coffee Shop  0.06
# 2          Bakery  0.06
# 3    Cocktail Bar  0.04
# 4  History Museum  0.04
#
#
# ----HENLEY ROAD----
#             venue  freq
# 0  Soccer Stadium  0.24
# 1           Hotel  0.12
# 2             Pub  0.12
# 3            Café  0.06
# 4   Movie Theater  0.06
#
#
# ----HENLEY STREET----
#                 venue  freq
# 0                 Pub  0.22
# 1                Café  0.06
# 2      Ice Cream Shop  0.04
# 3    Asian Restaurant  0.04
# 4  Turkish Restaurant  0.04
#
#
# ----HENRY ROAD----
#             venue  freq
# 0             Pub  0.12
# 1     Coffee Shop  0.06
# 2          Bakery  0.06
# 3    Cocktail Bar  0.04
# 4  History Museum  0.04
#
#
# ----HERTFORD STREET----
#                 venue  freq
# 0                 Pub  0.22
# 1                Café  0.06
# 2      Ice Cream Shop  0.04
# 3    Asian Restaurant  0.04
# 4  Turkish Restaurant  0.04
#
#
# ----HIGH STREET----
#            venue  freq
# 0            Pub  0.18
# 1  Grocery Store  0.12
# 2    Snack Place  0.06
# 3       Bus Stop  0.06
# 4   Amphitheater  0.06
#
#
# ----HOME CLOSE----
#                   venue  freq
# 0                 Hotel  0.19
# 1                   Pub  0.15
# 2            Canal Lock  0.07
# 3  Gym / Fitness Center  0.07
# 4        Farmers Market  0.04
#
#
# ----HOPE WAY----
#                  venue  freq
# 0          Supermarket  0.12
# 1        Grocery Store  0.12
# 2  Sporting Goods Shop  0.06
# 3              Brewery  0.06
# 4                  Pub  0.06
#
#
# ----HORWOOD CLOSE----
#             venue  freq
# 0             Pub  0.14
# 1   Grocery Store  0.10
# 2  Sandwich Place  0.06
# 3     Pizza Place  0.06
# 4            Café  0.06
#
#
# ----HOWARD STREET----
#                 venue  freq
# 0                 Pub  0.23
# 1    Asian Restaurant  0.04
# 2  Turkish Restaurant  0.04
# 3                Café  0.04
# 4                Park  0.04
#
#
# ----HUGH ALLEN CRESCENT----
#             venue  freq
# 0             Pub  0.12
# 1      Restaurant  0.06
# 2  History Museum  0.06
# 3  Ice Cream Shop  0.04
# 4     Coffee Shop  0.04
#
#
# ----HUTCHCOMB ROAD----
#            venue  freq
# 0    Supermarket  0.11
# 1  Grocery Store  0.11
# 2    IT Services  0.06
# 3        Brewery  0.06
# 4            Pub  0.06
#
#
# ----JACKSON ROAD----
#                 venue  freq
# 0               Hotel  0.15
# 1                 Pub  0.10
# 2  Chinese Restaurant  0.06
# 3       Grocery Store  0.06
# 4         Coffee Shop  0.06
#
#
# ----KELLYS ROAD----
#              venue  freq
# 0              Pub  0.11
# 1    Grocery Store  0.11
# 2      Snack Place  0.11
# 3  Motorcycle Shop  0.11
# 4             Food  0.11
#
#
# ----KENILWORTH AVENUE----
#                 venue  freq
# 0                 Pub  0.24
# 1                Café  0.06
# 2    Asian Restaurant  0.04
# 3  Turkish Restaurant  0.04
# 4                Park  0.04
#
#
# ----KINGSTON ROAD----
#             venue  freq
# 0             Pub  0.14
# 1      Restaurant  0.06
# 2     Coffee Shop  0.06
# 3  History Museum  0.06
# 4       Bookstore  0.04
#
#
# ----LANHAM WAY----
#                   venue  freq
# 0                   Pub  0.15
# 1        Soccer Stadium  0.11
# 2         Grocery Store  0.11
# 3                 Hotel  0.09
# 4  Gym / Fitness Center  0.04
#
#
# ----LAWN UPTON CLOSE----
#                   venue  freq
# 0                   Pub  0.15
# 1        Soccer Stadium  0.10
# 2         Grocery Store  0.10
# 3                 Hotel  0.08
# 4  Gym / Fitness Center  0.06
#
#
# ----LEIDEN ROAD----
#                   venue  freq
# 0                   Pub  0.12
# 1         Grocery Store  0.12
# 2           Supermarket  0.10
# 3           Coffee Shop  0.08
# 4  Gym / Fitness Center  0.06
#
#
# ----LIME WALK----
#             venue  freq
# 0             Pub  0.18
# 1  Sandwich Place  0.06
# 2     Supermarket  0.06
# 3     Pizza Place  0.04
# 4     Coffee Shop  0.04
#
#
# ----LONDON ROAD----
#             venue  freq
# 0             Pub  0.12
# 1            Café  0.10
# 2   Grocery Store  0.10
# 3     Supermarket  0.08
# 4  Sandwich Place  0.08
#
#
# ----MAGDALEN ROAD----
#                 venue  freq
# 0                 Pub  0.20
# 1      Ice Cream Shop  0.04
# 2    Asian Restaurant  0.04
# 3  Turkish Restaurant  0.04
# 4                Café  0.04
#
#
# ----MAIN STREET----
#                         venue  freq
# 0                   Rest Area  0.29
# 1                    Bus Stop  0.14
# 2                         Gym  0.14
# 3                     Parking  0.14
# 4  Construction & Landscaping  0.14
#
#
# ----MANOR DRIVE----
#                  venue  freq
# 0           Restaurant  0.25
# 1                Trail  0.25
# 2          Supermarket  0.25
# 3    Electronics Store  0.25
# 4  American Restaurant  0.00
#
#
# ----MANOR GROVE----
#            venue  freq
# 0            Pub   0.4
# 1          Hotel   0.2
# 2  Grocery Store   0.2
# 3     Restaurant   0.2
# 4           Park   0.0
#
#
# ----MARK ROAD----
#            venue  freq
# 0            Pub  0.12
# 1  Grocery Store  0.09
# 2    Supermarket  0.09
# 3           Café  0.09
# 4    Coffee Shop  0.07
#
#
# ----MARLBOROUGH ROAD----
#              venue  freq
# 0              Pub  0.10
# 1  Thai Restaurant  0.06
# 2        Bookstore  0.04
# 3     Cocktail Bar  0.04
# 4   History Museum  0.04
#
#
# ----MARSTON ROAD----
#             venue  freq
# 0             Pub  0.18
# 1  Sandwich Place  0.08
# 2     Supermarket  0.06
# 3     Coffee Shop  0.06
# 4      Restaurant  0.06
#
#
# ----MEADOW PROSPECT----
#                   venue  freq
# 0                   Pub  0.17
# 1                 Hotel  0.14
# 2           Coffee Shop  0.06
# 3                  Park  0.06
# 4  Gym / Fitness Center  0.06
#
#
# ----MOODY ROAD----
#               venue  freq
# 0               Pub  0.12
# 1    History Museum  0.06
# 2       Coffee Shop  0.04
# 3  Asian Restaurant  0.04
# 4         Bookstore  0.04
#
#
# ----MORRELL AVENUE----
#                 venue  freq
# 0                 Pub  0.20
# 1                Café  0.06
# 2      Ice Cream Shop  0.04
# 3    Asian Restaurant  0.04
# 4  Turkish Restaurant  0.04
#
#
# ----NEW ROAD----
#              venue  freq
# 0              Pub  0.10
# 1             Café  0.06
# 2   History Museum  0.06
# 3  Thai Restaurant  0.04
# 4       Restaurant  0.04
#
#
# ----NEWINGTON ROAD----
#                  venue  freq
# 0                Hotel  0.50
# 1          Gas Station  0.25
# 2    Food & Drink Shop  0.25
# 3  American Restaurant  0.00
# 4         Noodle House  0.00
#
#
# ----NICHOLSON ROAD----
#               venue  freq
# 0               Pub  0.14
# 1    History Museum  0.06
# 2              Park  0.04
# 3       Coffee Shop  0.04
# 4  Sushi Restaurant  0.04
#
#
# ----NORREYS AVENUE----
#               venue  freq
# 0               Pub  0.18
# 1   Thai Restaurant  0.06
# 2  Asian Restaurant  0.04
# 3       Coffee Shop  0.04
# 4         Bookstore  0.04
#
#
# ----NORREYS ROAD----
#                venue  freq
# 0           Bus Stop  0.18
# 1             Forest  0.18
# 2          Gastropub  0.18
# 3                Pub  0.18
# 4  College Cafeteria  0.09
#
#
# ----NORTH HINKSEY LANE----
#                venue  freq
# 0                Pub  0.14
# 1      Grocery Store  0.07
# 2        Supermarket  0.07
# 3  Indian Restaurant  0.04
# 4         Steakhouse  0.04
#
#
# ----OBSERVATORY STREET----
#             venue  freq
# 0             Pub  0.12
# 1     Coffee Shop  0.06
# 2          Bakery  0.06
# 3  History Museum  0.06
# 4      Restaurant  0.06
#
#
# ----OLD HIGH STREET----
#            venue  freq
# 0  Grocery Store  0.13
# 1            Pub  0.11
# 2           Café  0.09
# 3    Supermarket  0.07
# 4    Coffee Shop  0.07
#
#
# ----OXFORD ROAD----
#             venue  freq
# 0             Pub  0.18
# 1     Supermarket  0.08
# 2     Coffee Shop  0.06
# 3  Sandwich Place  0.06
# 4            Park  0.05
#
#
# ----PERCY STREET----
#                 venue  freq
# 0                 Pub  0.22
# 1      Ice Cream Shop  0.04
# 2    Asian Restaurant  0.04
# 3  Turkish Restaurant  0.04
# 4                Café  0.04
#
#
# ----POPLAR GROVE----
#            venue  freq
# 0            Pub   0.4
# 1          Hotel   0.2
# 2  Grocery Store   0.2
# 3     Restaurant   0.2
# 4           Park   0.0
#
#
# ----PRINCES STREET----
#                 venue  freq
# 0                 Pub  0.18
# 1                Café  0.06
# 2      Ice Cream Shop  0.04
# 3    Asian Restaurant  0.04
# 4  Turkish Restaurant  0.04
#
#
# ----QUARRY ROAD----
#            venue  freq
# 0            Pub  0.12
# 1  Grocery Store  0.10
# 2    Supermarket  0.10
# 3           Café  0.10
# 4    Coffee Shop  0.08
#
#
# ----RANDOLPH STREET----
#                 venue  freq
# 0                 Pub  0.22
# 1                Café  0.06
# 2      Ice Cream Shop  0.04
# 3    Asian Restaurant  0.04
# 4  Turkish Restaurant  0.04
#
#
# ----RECTORY ROAD----
#               venue  freq
# 0               Pub  0.18
# 1              Café  0.05
# 2             Hotel  0.05
# 3    Ice Cream Shop  0.04
# 4  Asian Restaurant  0.04
#
#
# ----RELIANCE WAY----
#                 venue  freq
# 0                 Pub  0.24
# 1                Café  0.04
# 2    Asian Restaurant  0.04
# 3  Turkish Restaurant  0.04
# 4                Park  0.04
#
#
# ----ROSE HILL----
#                   venue  freq
# 0                   Pub  0.22
# 1         Grocery Store  0.12
# 2                 Hotel  0.10
# 3  Gym / Fitness Center  0.06
# 4    Chinese Restaurant  0.04
#
#
# ----RYLANDS----
#             venue  freq
# 0             Pub  0.18
# 1  Sandwich Place  0.08
# 2     Coffee Shop  0.08
# 3   Grocery Store  0.08
# 4     Supermarket  0.06
#
#
# ----SHEEPWAY COURT----
#                     venue  freq
# 0                     Pub  0.26
# 1           Grocery Store  0.12
# 2                   Hotel  0.06
# 3             Pizza Place  0.06
# 4  Furniture / Home Store  0.04
#
#
# ----SOUTHFIELD ROAD----
#                 venue  freq
# 0                 Pub  0.22
# 1                Café  0.06
# 2         Pizza Place  0.04
# 3    Asian Restaurant  0.04
# 4  Turkish Restaurant  0.04
#
#
# ----ST LEONARDS ROAD----
#             venue  freq
# 0             Pub  0.11
# 1            Café  0.09
# 2   Grocery Store  0.09
# 3     Supermarket  0.07
# 4  Sandwich Place  0.07
#
#
# ----ST PETERS ROAD----
#                 venue  freq
# 0               Hotel  0.14
# 1                 Pub  0.12
# 2         Coffee Shop  0.06
# 3       Grocery Store  0.06
# 4  Chinese Restaurant  0.06
#
#
# ----STONE MEADOW----
#                 venue  freq
# 0                 Pub  0.22
# 1               Hotel  0.10
# 2              Bakery  0.08
# 3      History Museum  0.06
# 4  Chinese Restaurant  0.06
#
#
# ----SUNNINGWELL ROAD----
#               venue  freq
# 0               Pub  0.22
# 1   Thai Restaurant  0.06
# 2       Coffee Shop  0.04
# 3  Asian Restaurant  0.04
# 4         Bookstore  0.04
#
#
# ----TEMPLAR ROAD----
#                 venue  freq
# 0               Hotel  0.12
# 1  Chinese Restaurant  0.06
# 2       Grocery Store  0.06
# 3         Coffee Shop  0.06
# 4                 Pub  0.06
#
#
# ----TERRETT AVENUE----
#            venue  freq
# 0  Grocery Store  0.23
# 1       Bus Stop  0.15
# 2      Rest Area  0.15
# 3            Pub  0.15
# 4         Museum  0.08
#
#
# ----THAMES STREET----
#             venue  freq
# 0             Pub  0.08
# 1  History Museum  0.06
# 2    Cocktail Bar  0.04
# 3     Coffee Shop  0.04
# 4  Ice Cream Shop  0.04
#
#
# ----THE PARK----
#            venue  freq
# 0  Historic Site   0.2
# 1         Forest   0.2
# 2      Gastropub   0.2
# 3            Pub   0.2
# 4   Home Service   0.2
#
#
# ----THE SIDINGS----
#                 venue  freq
# 0       Grocery Store   0.2
# 1  English Restaurant   0.1
# 2                 Gym   0.1
# 3                Café   0.1
# 4                Food   0.1
#
#
# ----TIDMARSH LANE----
#              venue  freq
# 0              Pub  0.10
# 1             Café  0.06
# 2   History Museum  0.06
# 3  Thai Restaurant  0.04
# 4       Restaurant  0.04
#
#
# ----TREE LANE----
#            venue  freq
# 0            Pub  0.26
# 1  Grocery Store  0.12
# 2          Hotel  0.06
# 3    Pizza Place  0.06
# 4    Coffee Shop  0.04
#
#
# ----TURNPIKE ROAD----
#            venue  freq
# 0  Grocery Store  0.11
# 1      Gastropub  0.11
# 2    IT Services  0.06
# 3        Brewery  0.06
# 4            Pub  0.06
#
#
# ----ULFGAR ROAD----
#                 venue  freq
# 0               Hotel  0.14
# 1                 Pub  0.12
# 2         Coffee Shop  0.06
# 3       Grocery Store  0.06
# 4  Chinese Restaurant  0.06
#
#
# ----UNION STREET----
#                 venue  freq
# 0                 Pub  0.18
# 1                Café  0.06
# 2      Ice Cream Shop  0.04
# 3    Asian Restaurant  0.04
# 4  Turkish Restaurant  0.04
#
#
# ----WALTON STREET----
#             venue  freq
# 0             Pub  0.10
# 1     Coffee Shop  0.06
# 2          Bakery  0.06
# 3  History Museum  0.06
# 4      Restaurant  0.06
#
#
# ----WALTON WELL ROAD----
#             venue  freq
# 0             Pub  0.14
# 1     Coffee Shop  0.06
# 2      Restaurant  0.06
# 3  History Museum  0.06
# 4          Bakery  0.06
#
#
# ----WARREN HILL----
#                  venue  freq
# 0                Hotel  0.50
# 1          Gas Station  0.25
# 2    Food & Drink Shop  0.25
# 3  American Restaurant  0.00
# 4         Noodle House  0.00
#
#
# ----WELLBORNE ROAD----
#             venue  freq
# 0   Grocery Store  0.16
# 1             Pub  0.12
# 2            Café  0.09
# 3  Sandwich Place  0.07
# 4     Coffee Shop  0.07
#
#
# ----WELLBOURNE ROAD----
#             venue  freq
# 0   Grocery Store  0.16
# 1             Pub  0.12
# 2            Café  0.09
# 3  Sandwich Place  0.07
# 4     Coffee Shop  0.07
#
#
# ----WEST STREET----
#              venue  freq
# 0              Pub  0.08
# 1           Bakery  0.06
# 2  Thai Restaurant  0.04
# 3        Bookstore  0.04
# 4      Coffee Shop  0.04
#
#
# ----WEYLAND ROAD----
#            venue  freq
# 0            Pub  0.12
# 1  Grocery Store  0.09
# 2    Supermarket  0.09
# 3           Café  0.09
# 4    Coffee Shop  0.07
#
#
# ----WHITE HART----
#                 venue  freq
# 0       Grocery Store  0.16
# 1               Hotel  0.10
# 2          Restaurant  0.10
# 3  Chinese Restaurant  0.10
# 4              Bakery  0.06
#
#
# ----WHITE ROAD----
#                   venue  freq
# 0                   Pub  0.12
# 1         Grocery Store  0.12
# 2           Supermarket  0.09
# 3           Pizza Place  0.06
# 4  Gym / Fitness Center  0.06
#
#
# ----WOLSEY ROAD----
#                 venue  freq
# 0               Hotel  0.15
# 1         Coffee Shop  0.07
# 2  Chinese Restaurant  0.07
# 3       Grocery Store  0.07
# 4                 Pub  0.07
#
#
# ----WOOD AVENS WAY----
#             venue  freq
# 0   Grocery Store  0.16
# 1             Pub  0.12
# 2            Café  0.09
# 3  Sandwich Place  0.07
# 4     Coffee Shop  0.07
#
#
# ----WOODPERRY ROAD----
#                         venue  freq
# 0  Construction & Landscaping  0.25
# 1                   Gastropub  0.25
# 2                        Farm  0.25
# 3             Nature Preserve  0.25
# 4                      Museum  0.00
#
#
# ----WOODSTOCK CLOSE----
#                 venue  freq
# 0               Hotel  0.14
# 1                 Pub  0.10
# 2  Chinese Restaurant  0.06
# 3       Grocery Store  0.06
# 4         Coffee Shop  0.06
#
#
# ----WOODSTOCK ROAD----
#             venue  freq
# 0             Pub  0.12
# 1     Coffee Shop  0.06
# 2          Bakery  0.06
# 3  History Museum  0.06
# 4      Restaurant  0.06

# %%
#create pandas data frame and display top 10 venues in each neighborhood
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Street']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Street'] = oxford_gr['Street']

for ind in np.arange(oxford_gr.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(oxford_gr.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#             Street  ...       10th Most Common Venue
# 0    ABINGDON ROAD  ...  Eastern European Restaurant
# 1    ACREMEAD ROAD  ...               Cosmetics Shop
# 2     ALDRICH ROAD  ...                       Bakery
# 3  ARLINGTON DRIVE  ...                   Restaurant
# 4   ASHCROFT CLOSE  ...                    Wine Shop
#
# [5 rows x 11 columns]

# %%
neighborhoods_venues_sorted.shape
# Out:
# (123, 11)

# %% [markdown]
# ## 4. Data modelling
#
# After long process of data inspection and preparation we can move to the modelling stage. We will use k- Nearest Neighbors algorithm to cluster the neighborhoods by venues and facilities to determine the best location for the property search. We will create 5 clusters

# %%
#k-means for clustering
from sklearn.cluster import KMeans

kclusters = 5

ox_gr_clustering = oxford_gr.drop('Street', 1)

#run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(ox_gr_clustering)

#check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 

# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

neighborhoods_venues_sorted.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-38d07251137d> in <module>()
#      12
#      13 # add clustering labels
# ---> 14 neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
#      15
#      16 neighborhood_venues_sorted.head()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3494         self._ensure_valid_index(value)
#    3495         value = self._sanitize_column(column, value, broadcast=False)
# -> 3496         self._data.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3497
#    3498     def assign(self, **kwargs) -> "DataFrame":
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1171         if not allow_duplicates and item in self.items:
#    1172             # Should this be a different kind of error??
# -> 1173             raise ValueError(f"cannot insert {item}, already exists")
#    1174
#    1175         if not isinstance(loc, int):
#
# ValueError: cannot insert Cluster Labels, already exists

# %%
neighborhoods_venues_sorted.head()
# Out:
#    Cluster Labels  ...       10th Most Common Venue
# 0               1  ...  Eastern European Restaurant
# 1               0  ...               Cosmetics Shop
# 2               0  ...                       Bakery
# 3               2  ...                   Restaurant
# 4               0  ...                    Wine Shop
#
# [5 rows x 12 columns]

# %%
# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
ox_clustering= ox_av.join(neighborhoods_venues_sorted.set_index('Street'), on='Street')

ox_clustering
# Out:
#                Street  ...       10th Most Common Venue
# 2       ABINGDON ROAD  ...  Eastern European Restaurant
# 5       ACREMEAD ROAD  ...               Cosmetics Shop
# 10       ALDRICH ROAD  ...                       Bakery
# 28    ARLINGTON DRIVE  ...                   Restaurant
# 33     ASHCROFT CLOSE  ...                    Wine Shop
# ...               ...  ...                          ...
# 1133      WOLSEY ROAD  ...                       Bakery
# 1135   WOOD AVENS WAY  ...             Sculpture Garden
# 1145   WOODPERRY ROAD  ...                Deli / Bodega
# 1147  WOODSTOCK CLOSE  ...                     Pharmacy
# 1149   WOODSTOCK ROAD  ...                  Gaming Cafe
#
# [139 rows x 16 columns]

# %%
ox_clustering.shape
# Out:
# (139, 16)

# %% [markdown]
# ## 5. Visualization and Discussion
#
# To easier undestand our reasearch we can create the map of clusters and then examine each cluster on the most common venues.

# %%
#create the cluster map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=12)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(ox_clustering['Latitude'], ox_clustering['Longitude'], 
                                  ox_clustering['Street'],ox_clustering['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=10,
        popup=label,
        color=rainbow[cluster-1],
        fill = True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.5).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Examine Clusters

# %%
#Cluster 1
ox_clustering.loc[ox_clustering['Cluster Labels'] == 0, ox_clustering.columns[[1] + list(range(5, ox_clustering.shape[1]))]]
# Out:
#       Postcode  Cluster Labels  ...   9th Most Common Venue 10th Most Common Venue
# 5     OX33 1NZ               0  ...       Convenience Store         Cosmetics Shop
# 10     OX2 7SS               0  ...    Gym / Fitness Center                 Bakery
# 33     OX2 9SE               0  ...  Furniture / Home Store              Wine Shop
# 62     OX2 7JH               0  ...    Gym / Fitness Center                 Bakery
# 131    OX3 9FZ               0  ...    Fast Food Restaurant       Sculpture Garden
# ...        ...             ...  ...                     ...                    ...
# 1117   OX3 0PL               0  ...       Indian Restaurant                   Café
# 1119   OX4 2JL               0  ...           Shopping Mall          Go Kart Track
# 1133   OX2 7TA               0  ...    Gym / Fitness Center                 Bakery
# 1135   OX3 9GA               0  ...    Fast Food Restaurant       Sculpture Garden
# 1147   OX2 8DB               0  ...                    Park               Pharmacy
#
# [65 rows x 12 columns]

# %%
#Cluster 2
ox_clustering.loc[ox_clustering['Cluster Labels'] == 1, ox_clustering.columns[[1] + list(range(5, ox_clustering.shape[1]))]]
# Out:
#       Postcode  ...       10th Most Common Venue
# 2      OX2 9QN  ...  Eastern European Restaurant
# 107    OX2 9PS  ...            Electronics Store
# 170    OX4 1QN  ...  Eastern European Restaurant
# 243    OX4 3NN  ...                        Hotel
# 257    OX4 2DL  ...                  Record Shop
# 309    OX4 1LN  ...        Portuguese Restaurant
# 329    OX4 1XR  ...                        Plaza
# 388    OX4 3PW  ...           Chinese Restaurant
# 463    OX3 7SU  ...           Turkish Restaurant
# 464    OX3 7TA  ...           Turkish Restaurant
# 472    OX4 1ER  ...                  Record Shop
# 473    OX4 1ES  ...                  Record Shop
# 486    OX4 3AL  ...                  Record Shop
# 527    OX4 3BE  ...                   Canal Lock
# 528    OX4 3BG  ...                   Canal Lock
# 570    OX4 2AW  ...                   Canal Lock
# 623    OX3 7AF  ...                Deli / Bodega
# 658    OX4 1RB  ...                        Plaza
# 661   OX33 1DZ  ...                Deli / Bodega
# 718    OX4 1NA  ...                        Plaza
# 738    OX1 4SS  ...                  Record Shop
# 739    OX2 9PT  ...                 Concert Hall
# 740    OX2 9PU  ...                 Concert Hall
# 817    OX4 3AA  ...        Portuguese Restaurant
# 843    OX4 1DE  ...               Sandwich Place
# 855    OX4 1YA  ...                        Plaza
# 857    OX4 1BU  ...                 Dessert Shop
# 860   OX44 7JG  ...                 Dessert Shop
# 864    OX4 2FU  ...        Portuguese Restaurant
# 940    OX4 1NZ  ...                  Record Shop
# 994    OX1 4SZ  ...               Ice Cream Shop
# 1031   OX2 9QS  ...  Eastern European Restaurant
# 1060   OX4 1JP  ...                  Record Shop
#
# [33 rows x 12 columns]

# %%
#Cluster 3
ox_clustering.loc[ox_clustering['Cluster Labels'] == 2, ox_clustering.columns[[1] + list(range(5, ox_clustering.shape[1]))]]
# Out:
#      Postcode  Cluster Labels  ... 9th Most Common Venue     10th Most Common Venue
# 28    OX3 0SL               2  ...       Thai Restaurant                 Restaurant
# 116   OX2 7HJ               2  ...                Church                   Pharmacy
# 139   OX2 0EZ               2  ...        Ice Cream Shop         Chinese Restaurant
# 140   OX2 0HW               2  ...        Ice Cream Shop         Chinese Restaurant
# 246   OX3 0SG               2  ...        History Museum          French Restaurant
# 286   OX2 7BL               2  ...                  Park  Middle Eastern Restaurant
# 324   OX2 0HX               2  ...             Bookstore                      Hotel
# 336   OX3 0HE               2  ...             Roof Deck                Record Shop
# 368   OX2 0BY               2  ...        Ice Cream Shop                 Restaurant
# 380   OX1 1HT               2  ...             Bookstore             Ice Cream Shop
# 460   OX3 0SF               2  ...        History Museum                     Bakery
# 466   OX2 0DF               2  ...                 Canal                      Hotel
# 474   OX2 0DG               2  ...                 Canal                      Hotel
# 531   OX3 0HN               2  ...           Gaming Cafe               Cocktail Bar
# 588   OX2 6RH               2  ...          Cocktail Bar          Indian Restaurant
# 674   OX1 4LS               2  ...           Coffee Shop                Record Shop
# 715   OX3 0DH               2  ...            Restaurant                Record Shop
# 731   OX1 1AY               2  ...       Thai Restaurant             Ice Cream Shop
# 733   OX3 0HW               2  ...                Bakery                       Park
# 761   OX2 6EP               2  ...             Bookstore                Gaming Cafe
# 985   OX2 6TQ               2  ...           Coffee Shop         English Restaurant
# 1011  OX1 1SU               2  ...           Coffee Shop                  Bookstore
# 1041  OX1 1AZ               2  ...       Thai Restaurant             Ice Cream Shop
# 1081  OX2 6ER               2  ...          Cocktail Bar                       Park
# 1084  OX2 6GF               2  ...        Sandwich Place               Cocktail Bar
# 1103  OX2 0BH               2  ...        History Museum                Coffee Shop
# 1104  OX2 0BQ               2  ...        History Museum                Coffee Shop
# 1145  OX3 9UZ               2  ...        Cosmetics Shop              Deli / Bodega
# 1149  OX2 6EY               2  ...             Bookstore                Gaming Cafe
#
# [29 rows x 12 columns]

# %%
#Cluster 4
ox_clustering.loc[ox_clustering['Cluster Labels'] == 3, ox_clustering.columns[[1] + list(range(5, ox_clustering.shape[1]))]]
# Out:
#       Postcode  ...       10th Most Common Venue
# 251    OX4 4JB  ...                 Cocktail Bar
# 261   OX33 1HW  ...                Deli / Bodega
# 285    OX1 5JP  ...                Deli / Bodega
# 338    OX4 4JF  ...                         Park
# 395    OX1 5DS  ...             Department Store
# 411   OX33 1TD  ...  Eastern European Restaurant
# 667    OX1 5QY  ...             Department Store
# 838    OX1 5QS  ...             Department Store
# 912    OX4 4JL  ...                  College Gym
# 1047   OX4 4EX  ...                  College Gym
#
# [10 rows x 12 columns]

# %%
#Cluster 5
ox_clustering.loc[ox_clustering['Cluster Labels'] == 4, ox_clustering.columns[[1] + list(range(5, ox_clustering.shape[1]))]]
# Out:
#       Postcode  Cluster Labels  ... 9th Most Common Venue 10th Most Common Venue
# 732   OX44 7UU               4  ...          Dessert Shop       Department Store
# 1088  OX44 7UT               4  ...          Dessert Shop       Department Store
#
# [2 rows x 12 columns]

# %% [markdown]
# ### Discussion
#
# Let's look at the clusters venues.
# Cluster 1 has plenty of grocery stores and supermarkets, parks, hotels, restaraunts bus station and the shopping mall.
# Cluster 2 has a lot of restaraunts/cafes, museums, historic site, bus stops and karting.
# Cluster 3 has museums, restaurants, the Canal, coffee shops and book store.
# Cluster 4 has a grocery stores, some hotels, gym, a few number of restaraunts and no parks or green area.
# Cluster 5 is a remote location with a limited number of venues.
#
# From the venues/amenities point of view cluster 1 and 2 are the most attractive as they contain not only restaraunts, grocery stores, hotels, but also a transportation facilities.

# %% [markdown]
# ## 6. Conclusion
#
# As the housing market slowing down due to pandemic and prices are droping it is a good time to make an investment as per expert's opinion the market will come back after the pandemic. According to McKenzie research up to 60% of property performance is coming from non-traditional features such as facilities and amenities of the location.
# With the lock down in place it is not possible to study the area on the foot, it is also would take a longer time to do that in a normal conditions.
#
# We have used data science methdology to cluster the area of Oxford city to define the most attractive locations for the investment.
# The data used for the research were downloaded from public HM Land Registry data base. FourSquare API was used to define most common amenities/venues.
#
# We followed the workflow of exploring the data, understanding it, pre-processing and processing to create Pandas data frames. We then used k-Nearest Neighbours algorithm to find the similarities of the properties locations and created 5 clusters.
#
# We have visualized the area in terms of average property price distribution and cluster spread by creating the maps.
#
# From the cluster examination we found that cluster 1 and 2 are most attractive for the investor as they have most diverse venues, though some may look for different features when investing on property market.
